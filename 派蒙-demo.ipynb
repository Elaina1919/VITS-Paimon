# %%
import IPython.display as ipd
import vitschatgpt
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1054)
#            2	LOAD_FAST(arg=0, lineno=1054)
#            4	LOAD_CONST(arg=1, lineno=1054)
#            6	BINARY_SUBSCR(arg=None, lineno=1054)
#            8	LOAD_FAST(arg=0, lineno=1054)
#           10	LOAD_CONST(arg=2, lineno=1054)
#           12	BINARY_SUBSCR(arg=None, lineno=1054)
#           14	COMPARE_OP(arg=4, lineno=1054)
#           16	LOAD_FAST(arg=0, lineno=1054)
#           18	LOAD_CONST(arg=1, lineno=1054)
#           20	BINARY_SUBSCR(arg=None, lineno=1054)
#           22	LOAD_FAST(arg=0, lineno=1054)
#           24	LOAD_CONST(arg=3, lineno=1054)
#           26	BINARY_SUBSCR(arg=None, lineno=1054)
#           28	COMPARE_OP(arg=5, lineno=1054)
#           30	BINARY_AND(arg=None, lineno=1054)
#           32	RETURN_VALUE(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# ...

# %%
chatbot = vitschatgpt.VitsChatGPT("configs/biaobei_base.json", "model_pt/G_1434000.pth", "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")
# Out:
# INFO:root:Loaded checkpoint 'model_pt/G_1434000.pth' (iteration 1791)

# %%
audio1, text1 = chatbot.ask("下面请扮演原神里的派蒙，在对话中请称呼我为旅行者")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.openai.com:443
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/chat/completions HTTP/1.1" 200 None

# %%
print(text1)
# Out:
# 好的，旅行者，你好呀！很高兴能和你聊天。
#
# 你在这片大陆上旅行的怎么样啊？有没有遇到什么有趣的事情？

# %%
ipd.display(audio1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio2, text2 = chatbot.ask("如果我走到了地图边界你会说什么")
# Out:
# DEBUG:urllib3.connectionpool:Resetting dropped connection: api.openai.com
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/chat/completions HTTP/1.1" 200 None

# %%
print(text2)
ipd.display(audio2)
# Out:
# 如果你走到了地图边界，我会告诉你：旅行者，你已经到了这片大陆的边缘了。在这个世界中，有很多神秘的地方等待着你去探索，但是也有一些地方是无法到达的。不过，不要担心，这片大陆上还有很多其他美丽、神秘的地方等待着你去发现。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio3, text3 = chatbot.ask("请重复这句话：前面的地区以后再来探索吧")
# Out:
# DEBUG:urllib3.connectionpool:Resetting dropped connection: api.openai.com
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/chat/completions HTTP/1.1" 200 None

# %%
print(text3)
ipd.display(audio3)
# Out:
# 好的，我会重复这句话：前面的地区以后再来探索吧。有时候在游戏中，我们可能会遇到一些比较困难的关卡或地点，这时候可以先去其他地方转转，提升自己的实力，再回来挑战。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio4, text4 = chatbot.ask("你在游戏里最喜欢的食物是什么")
# Out:
# DEBUG:urllib3.connectionpool:Resetting dropped connection: api.openai.com
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/chat/completions HTTP/1.1" 200 None

# %%
print(text4)
ipd.display(audio4)
# Out:
# 作为一只派蒙，我其实不需要食物来维持生命。不过，如果要我在游戏里选择一种最喜欢的食物的话，我还是会选择鸟蛋。毕竟，它是我和旅行者们最常见的食物之一，而且还可以用来制作许多美味的料理。不知道旅行者你喜欢吃什么食物呢？
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
